# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Joel Elí Orellana Martínez
#
# Fecha: 27/04/2023
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Named-Entity Recognition</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno se familiarice con el manejo de la librería spacy, así como con los conceptos básicos de manejo de las técnicas NER
#
# **Descripción**
#
# En esta actividad debes procesar de forma automática un texto en lenguaje natural para detectar características básicas en el mismo, y para identificar y etiquetar las ocurrencias de conceptos como localización, moneda, empresas, etc.
#
# En la primera parte del ejercicio se proporciona un código fuente a través del cual se lee un archivo de texto y se realiza un preprocesado del mismo. En esta parte el alumno tan sólo debe ejecutar y entender el código proporcionado.
#
# En la segunda parte del ejercicio se plantean una serie de preguntas que deben ser respondidas por el alumno. Cada pregunta deberá responderse con un fragmento de código fuente que esté acompañado de la explicación correspondiente. Para elaborar el código solicitado, el alumno deberá visitar la documentación de la librería spacy, cuyos enlaces se proporcionarán donde corresponda.

# %% [markdown]
# # Parte 1: carga y preprocesamiento del texto a analizar

# %% [markdown]
# Observa las diferentes librerías que se están importando.

# %%
import pathlib
import spacy
from spacy import displacy
import en_core_web_sm

# %% [markdown]
# El siguiente código simplemente carga y preprocesa el texto. Para ello, lo primero que hace es cargar un modelo de lenguaje previamente entrenado. En este caso, se utiliza <i>en_core_web_sm</i>:
#
# https://spacy.io/models/en#en_core_web_sm
#
# Al cargar el modelo de lenguaje se genera un <i>Pipeline</i>, que nos permite realizar las diferentes tareas. En este caso, vamos a utilizar el pipeline para hacer un preprocesamiento básico, que consiste en tokenizar el texto.
#
# Al final del código proporcionado <i>doc</i> representa una versión tokenizada del texto leído.

# %%
# Trabajaré desde Google Colab, por lo que vamos a importar el drive y cargar el drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
nlp = en_core_web_sm.load()
file_name = "barack-obama-speech.txt"
doc = nlp(pathlib.Path('/content/gdrive/MyDrive/Colab Notebooks/PLN_ACT1/'+file_name).read_text(encoding="utf-8"))

# %% [markdown]
# ### Playground
#
# La variable <i>doc</i> es un objeto de la clase <i>Doc</i> (https://spacy.io/api/doc)
#
# Visita la documentación de dicha clase y experimenta probando las diferentes funciones y atributos

# %%
# Puedes insertar aquí código de pruebas para experimentar con las diferentes funciones y atributos de 'doc'.
# creando una funcion para mostrar las entidades
def show_ents(doc):
    for ent in doc.ents:
        print(ent.text, ent.label_, str(spacy.explain(ent.label_)), ent.start_char, ent.end_char)
show_ents(doc)
# la funcion anterior muestra:
# 1. el texto de la entidad con ent.text
# 2. el tipo de la entidad con ent.label_
# 3. el tipo de entidad con spacy.explain(ent.label_)
# 4. el inicio de la entidad con ent.start_char
# 5. el fin de la entidad con ent.end_char
# Out:
# Chicago GPE Countries, cities, states 8 15
# America GPE Countries, cities, states 68 75
# tonight TIME Times smaller than a day 235 242
# three hours TIME Times smaller than a day 392 403
# four hours TIME Times smaller than a day 408 418
# first ORDINAL "first", "second", etc. 433 438
# Democrat NORP Nationalities or religious or political groups 616 624
# Republican NORP Nationalities or religious or political groups 629 639
# Hispanic NORP Nationalities or religious or political groups 655 663
# Asian NORP Nationalities or religious or political groups 665 670
# Native American NORP Nationalities or religious or political groups 672 687
# Americans NORP Nationalities or religious or political groups 731 740
# the United States of America GPE Countries, cities, states 905 933
# tonight TIME Times smaller than a day 1201 1208
# America GPE Countries, cities, states 1306 1313
# Washington GPE Countries, cities, states 1427 1437
# Des Moines GPE Countries, cities, states 1468 1478
# Concord GPE Countries, cities, states 1503 1510
# Charleston GPE Countries, cities, states 1536 1546
# $5 and $10 and $20 MONEY Monetary values, including unit 1636 1654
# millions CARDINAL Numerals that do not fall under another type 1993 2001
# Americans NORP Nationalities or religious or political groups 2005 2014
# more than two centuries later DATE Absolute or relative dates or periods 2061 2090
# Earth LOC Non-GPE locations, mountain ranges, bodies of water 2179 2184
# tonight TIME Times smaller than a day 2400 2407
# tomorrow DATE Absolute or relative dates or periods 2437 2445
# two CARDINAL Numerals that do not fall under another type 2492 2495
# a century DATE Absolute or relative dates or periods 2551 2560
# tonight TIME Times smaller than a day 2584 2591
# Americans NORP Nationalities or religious or political groups 2617 2626
# Iraq GPE Countries, cities, states 2655 2659
# Afghanistan GPE Countries, cities, states 2681 2692
# one year DATE Absolute or relative dates or periods 3119 3127
# one CARDINAL Numerals that do not fall under another type 3139 3142
# America GPE Countries, cities, states 3154 3161
# tonight TIME Times smaller than a day 3204 3211
# America GPE Countries, cities, states 3684 3691
# 221 years DATE Absolute or relative dates or periods 3696 3705
# 21 months ago DATE Absolute or relative dates or periods 3785 3798
# winter DATE Absolute or relative dates or periods 3816 3822
# this autumn night TIME Times smaller than a day 3837 3854
# Main Street FAC Buildings, airports, highways, bridges, etc. 4391 4402
# one CARDINAL Numerals that do not fall under another type 4448 4451
# one CARDINAL Numerals that do not fall under another type 4463 4466
# first ORDINAL "first", "second", etc. 4667 4672
# the Republican Party ORG Companies, agencies, institutions, etc. 4695 4715
# the White House ORG Companies, agencies, institutions, etc. 4719 4734
# the Democratic Party ORG Companies, agencies, institutions, etc. 4872 4892
# tonight TIME Times smaller than a day 4917 4924
# Lincoln ORG Companies, agencies, institutions, etc. 5037 5044
# Americans NORP Nationalities or religious or political groups 5211 5220
# tonight TIME Times smaller than a day 5284 5291
# tonight TIME Times smaller than a day 5396 5403
# American NORP Nationalities or religious or political groups 5607 5615
# America GPE Countries, cities, states 5802 5809
# Tonight TIME Times smaller than a day 5842 5849
# America GPE Countries, cities, states 6094 6101
# America GPE Countries, cities, states 6108 6115
# tomorrow DATE Absolute or relative dates or periods 6231 6239
# tonight TIME Times smaller than a day 6349 6356
# Atlanta GPE Countries, cities, states 6396 6403
# millions CARDINAL Numerals that do not fall under another type 6426 6434
# one CARDINAL Numerals that do not fall under another type 6517 6520
# Ann Nixon Cooper PERSON People, including fictional 6528 6544
# 106 years old DATE Absolute or relative dates or periods 6548 6561
# two CARDINAL Numerals that do not fall under another type 6713 6716
# tonight TIME Times smaller than a day 6793 6800
# America GPE Countries, cities, states 6862 6869
# American NORP Nationalities or religious or political groups 7009 7017
# Montgomery ORG Companies, agencies, institutions, etc. 7564 7574
# Birmingham GPE Countries, cities, states 7589 7599
# Selma GPE Countries, cities, states 7613 7618
# Atlanta GPE Countries, cities, states 7640 7647
# the moon LOC Non-GPE locations, mountain ranges, bodies of water 7726 7734
# Berlin GPE Countries, cities, states 7756 7762
# this year DATE Absolute or relative dates or periods 7826 7835
# 106 years DATE Absolute or relative dates or periods 7924 7933
# America GPE Countries, cities, states 7937 7944
# hours TIME Times smaller than a day 7991 7996
# America GPE Countries, cities, states 8012 8019
# America GPE Countries, cities, states 8044 8051
# tonight TIME Times smaller than a day 8132 8139
# the next century DATE Absolute or relative dates or periods 8199 8215
# Ann Nixon Cooper PERSON People, including fictional 8271 8287
# American NORP Nationalities or religious or political groups 8571 8579

# %% [markdown]
# # Parte 2: preguntas

# %% [markdown]
# Para responder a cada una de las preguntas planteadas deberás aportar tanto el código fuente con el cual puedes conseguir la respuesta, como una explicación válida de la respuesta y de la forma de obtenerla.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 1.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# R/ Se puede contar el numero de tokens del objeto doc
word_count = 0
for token in doc:
    if not token.is_punct and not token.is_space: # si el token no es punto ni espacio, entonces es una palabra
        word_count += 1
print(str(word_count) + ' palabras')
# Out:
# 1686 palabras

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# Para contar todas las palabras se realizará un recorrido o iteración sobre el documento, se cuenta una palabra como válida siempre que no sea signo de puntuación, lo que se verifica con token.is_punct y token.is_space para verificar que no sea un espacio en blanco.
#
# El contador muestra al final un total de 1686 palabras.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 2.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas oraciones tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
sents = [sent for sent in doc.sents] # se obtiene una lista de oraciones del objeto doc
len(sents) # se obtiene el numero de oraciones
# Out:
# 83

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#  Por medio del atributo sents del objeto doc, podemos obtener todas las oraciones del texto, la lista comprimida sirva para extraer oración por oración cada una de las que se encuentran en el texto. Finalmente, se calcula el tamaño de la lista de oraciones con len(sents).
# El total de oraciones en el texto es de 83.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 3.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuál el número de palabras de la oración más grande? ¿Cual es dicha oración?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
longest = max(sents, key=lambda sent: len(sent))
print(f'La oración más larga es "{longest}" con {len(longest)} palabras')
# Out:
# La oración más larga es "It drew strength from the not-so-young people who braved the bitter cold and scorching heat to knock on doors of perfect strangers, and from the millions of Americans who volunteered and organized and proved that more than two centuries later a government of the people, by the people, and for the people has not perished from the Earth.
# " con 67 palabras

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# Por medio de una función anónima utilizando lambda, se encuentra el tamaño de cada oracion de la lista sents, la función max sirve para devolver la oración de mayor longitud.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 4.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes acceder al lema, lexema y morfemas de cada token?</span>
#
# Recomendación: si no lo has hecho ya, visita la documentación de la clase <i>Token</i>: https://spacy.io/api/token

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# he encontrado lexema en https://spacy.io/usage/spacy-101
for token in doc:
    if not token.is_punct and not token.is_space:
        lexeme = token.lex.text
        lemma = token.lemma_
        morphema = token.morph
        print(f"TOKEN: {token}, LEXEMA: {lexeme}, LEMMA: {lemma}, MORPHEMA: {morphema}")
# Out:
# TOKEN: Hello, LEXEMA: Hello, LEMMA: Hello, MORPHEMA: Number=Sing
# TOKEN: Chicago, LEXEMA: Chicago, LEMMA: Chicago, MORPHEMA: Number=Sing
# TOKEN: If, LEXEMA: If, LEMMA: if, MORPHEMA:
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA:
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: anyone, LEXEMA: anyone, LEMMA: anyone, MORPHEMA: Number=Sing|PronType=Ind
# TOKEN: out, LEXEMA: out, LEMMA: out, MORPHEMA:
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA: PronType=Dem
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: still, LEXEMA: still, LEMMA: still, MORPHEMA:
# TOKEN: doubts, LEXEMA: doubts, LEMMA: doubt, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: place, LEXEMA: place, LEMMA: place, MORPHEMA: Number=Sing
# TOKEN: where, LEXEMA: where, LEMMA: where, MORPHEMA:
# TOKEN: all, LEXEMA: all, LEMMA: all, MORPHEMA:
# TOKEN: things, LEXEMA: things, LEMMA: thing, MORPHEMA: Number=Plur
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: possible, LEXEMA: possible, LEMMA: possible, MORPHEMA: Degree=Pos
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: still, LEXEMA: still, LEMMA: still, MORPHEMA:
# TOKEN: wonders, LEXEMA: wonders, LEMMA: wonder, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: if, LEXEMA: if, LEMMA: if, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: dream, LEXEMA: dream, LEMMA: dream, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: founders, LEXEMA: founders, LEMMA: founder, MORPHEMA: Number=Plur
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: alive, LEXEMA: alive, LEMMA: alive, MORPHEMA: Degree=Pos
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: time, LEXEMA: time, LEMMA: time, MORPHEMA: Number=Sing
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: still, LEXEMA: still, LEMMA: still, MORPHEMA:
# TOKEN: questions, LEXEMA: questions, LEMMA: question, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: power, LEXEMA: power, LEMMA: power, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: democracy, LEXEMA: democracy, LEMMA: democracy, MORPHEMA: Number=Sing
# TOKEN: tonight, LEXEMA: tonight, LEMMA: tonight, MORPHEMA: Number=Sing
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: your, LEXEMA: your, LEMMA: your, MORPHEMA: Person=2|Poss=Yes|PronType=Prs
# TOKEN: answer, LEXEMA: answer, LEMMA: answer, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: answer, LEXEMA: answer, LEMMA: answer, MORPHEMA: Number=Sing
# TOKEN: told, LEXEMA: told, LEMMA: tell, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: lines, LEXEMA: lines, LEMMA: line, MORPHEMA: Number=Plur
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: PronType=Rel
# TOKEN: stretched, LEXEMA: stretched, LEMMA: stretch, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: around, LEXEMA: around, LEMMA: around, MORPHEMA:
# TOKEN: schools, LEXEMA: schools, LEMMA: school, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: churches, LEXEMA: churches, LEMMA: church, MORPHEMA: Number=Plur
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: numbers, LEXEMA: numbers, LEMMA: number, MORPHEMA: Number=Plur
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: nation, LEXEMA: nation, LEMMA: nation, MORPHEMA: Number=Sing
# TOKEN: has, LEXEMA: has, LEMMA: have, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: never, LEXEMA: never, LEMMA: never, MORPHEMA:
# TOKEN: seen, LEXEMA: seen, LEMMA: see, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: waited, LEXEMA: waited, LEMMA: wait, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: three, LEXEMA: three, LEMMA: three, MORPHEMA: NumType=Card
# TOKEN: hours, LEXEMA: hours, LEMMA: hour, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: four, LEXEMA: four, LEMMA: four, MORPHEMA: NumType=Card
# TOKEN: hours, LEXEMA: hours, LEMMA: hour, MORPHEMA: Number=Plur
# TOKEN: many, LEXEMA: many, LEMMA: many, MORPHEMA: Degree=Pos
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: first, LEXEMA: first, LEMMA: first, MORPHEMA: Degree=Pos
# TOKEN: time, LEXEMA: time, LEMMA: time, MORPHEMA: Number=Sing
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: lives, LEXEMA: lives, LEMMA: life, MORPHEMA: Number=Plur
# TOKEN: because, LEXEMA: because, LEMMA: because, MORPHEMA:
# TOKEN: they, LEXEMA: they, LEMMA: they, MORPHEMA: Case=Nom|Number=Plur|Person=3|PronType=Prs
# TOKEN: believed, LEXEMA: believed, LEMMA: believe, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: time, LEXEMA: time, LEMMA: time, MORPHEMA: Number=Sing
# TOKEN: must, LEXEMA: must, LEMMA: must, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: different, LEXEMA: different, LEMMA: different, MORPHEMA: Degree=Pos
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: voices, LEXEMA: voices, LEMMA: voice, MORPHEMA: Number=Plur
# TOKEN: could, LEXEMA: could, LEMMA: could, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: difference, LEXEMA: difference, LEMMA: difference, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: answer, LEXEMA: answer, LEMMA: answer, MORPHEMA: Number=Sing
# TOKEN: spoken, LEXEMA: spoken, LEMMA: speak, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: young, LEXEMA: young, LEMMA: young, MORPHEMA: Degree=Pos
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: old, LEXEMA: old, LEMMA: old, MORPHEMA: Degree=Pos
# TOKEN: rich, LEXEMA: rich, LEMMA: rich, MORPHEMA: Degree=Pos
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: poor, LEXEMA: poor, LEMMA: poor, MORPHEMA: Degree=Pos
# TOKEN: Democrat, LEXEMA: Democrat, LEMMA: Democrat, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: Republican, LEXEMA: Republican, LEMMA: Republican, MORPHEMA: Number=Sing
# TOKEN: black, LEXEMA: black, LEMMA: black, MORPHEMA: Degree=Pos
# TOKEN: white, LEXEMA: white, LEMMA: white, MORPHEMA: Degree=Pos
# TOKEN: Hispanic, LEXEMA: Hispanic, LEMMA: hispanic, MORPHEMA: Degree=Pos
# TOKEN: Asian, LEXEMA: Asian, LEMMA: asian, MORPHEMA: Degree=Pos
# TOKEN: Native, LEXEMA: Native, LEMMA: Native, MORPHEMA: Number=Sing
# TOKEN: American, LEXEMA: American, LEMMA: American, MORPHEMA: Number=Sing
# TOKEN: gay, LEXEMA: gay, LEMMA: gay, MORPHEMA: Degree=Pos
# TOKEN: straight, LEXEMA: straight, LEMMA: straight, MORPHEMA: Degree=Pos
# TOKEN: disabled, LEXEMA: disabled, LEMMA: disabled, MORPHEMA: Degree=Pos
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: not, LEXEMA: not, LEMMA: not, MORPHEMA: Polarity=Neg
# TOKEN: disabled, LEXEMA: disabled, LEMMA: disabled, MORPHEMA: Degree=Pos
# TOKEN: Americans, LEXEMA: Americans, LEMMA: american, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: sent, LEXEMA: sent, LEMMA: send, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: message, LEXEMA: message, LEMMA: message, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: world, LEXEMA: world, LEMMA: world, MORPHEMA: Number=Sing
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: have, LEXEMA: have, LEMMA: have, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: never, LEXEMA: never, LEMMA: never, MORPHEMA:
# TOKEN: been, LEXEMA: been, LEMMA: be, MORPHEMA: Tense=Past|VerbForm=Part
# TOKEN: just, LEXEMA: just, LEMMA: just, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: collection, LEXEMA: collection, LEMMA: collection, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: individuals, LEXEMA: individuals, LEMMA: individual, MORPHEMA: Number=Plur
# TOKEN: or, LEXEMA: or, LEMMA: or, MORPHEMA: ConjType=Cmp
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: collection, LEXEMA: collection, LEMMA: collection, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: red, LEXEMA: red, LEMMA: red, MORPHEMA: Degree=Pos
# TOKEN: states, LEXEMA: states, LEMMA: state, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: blue, LEXEMA: blue, LEMMA: blue, MORPHEMA: Degree=Pos
# TOKEN: states, LEXEMA: states, LEMMA: state, MORPHEMA: Number=Plur
# TOKEN: We, LEXEMA: We, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: always, LEXEMA: always, LEMMA: always, MORPHEMA:
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: United, LEXEMA: United, LEMMA: United, MORPHEMA: Number=Sing
# TOKEN: States, LEXEMA: States, LEMMA: States, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: answer, LEXEMA: answer, LEMMA: answer, MORPHEMA: Number=Sing
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: PronType=Rel
# TOKEN: led, LEXEMA: led, LEMMA: lead, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: those, LEXEMA: those, LEMMA: those, MORPHEMA: Number=Plur|PronType=Dem
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: ’ve, LEXEMA: ’ve, LEMMA: ’ve, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: been, LEXEMA: been, LEMMA: been, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: told, LEXEMA: told, LEMMA: tell, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: long, LEXEMA: long, LEMMA: long, MORPHEMA:
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: many, LEXEMA: many, LEMMA: many, MORPHEMA: Degree=Pos
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: cynical, LEXEMA: cynical, LEMMA: cynical, MORPHEMA: Degree=Pos
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: fearful, LEXEMA: fearful, LEMMA: fearful, MORPHEMA: Degree=Pos
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: doubtful, LEXEMA: doubtful, LEMMA: doubtful, MORPHEMA: Degree=Pos
# TOKEN: about, LEXEMA: about, LEMMA: about, MORPHEMA:
# TOKEN: what, LEXEMA: what, LEMMA: what, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: can, LEXEMA: can, LEMMA: can, MORPHEMA: VerbForm=Fin
# TOKEN: achieve, LEXEMA: achieve, LEMMA: achieve, MORPHEMA: VerbForm=Inf
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: put, LEXEMA: put, LEMMA: put, MORPHEMA: VerbForm=Inf
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: hands, LEXEMA: hands, LEMMA: hand, MORPHEMA: Number=Plur
# TOKEN: on, LEXEMA: on, LEMMA: on, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: arc, LEXEMA: arc, LEMMA: arc, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: history, LEXEMA: history, LEMMA: history, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: bend, LEXEMA: bend, LEMMA: bend, MORPHEMA: VerbForm=Inf
# TOKEN: it, LEXEMA: it, LEMMA: it, MORPHEMA: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: once, LEXEMA: once, LEMMA: once, MORPHEMA: NumType=Mult
# TOKEN: more, LEXEMA: more, LEMMA: more, MORPHEMA: Degree=Cmp
# TOKEN: toward, LEXEMA: toward, LEMMA: toward, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: hope, LEXEMA: hope, LEMMA: hope, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: better, LEXEMA: better, LEMMA: well, MORPHEMA: Degree=Cmp
# TOKEN: day, LEXEMA: day, LEMMA: day, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’s, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: been, LEXEMA: been, LEMMA: be, MORPHEMA: Tense=Past|VerbForm=Part
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: long, LEXEMA: long, LEMMA: long, MORPHEMA: Degree=Pos
# TOKEN: time, LEXEMA: time, LEMMA: time, MORPHEMA: Number=Sing
# TOKEN: coming, LEXEMA: coming, LEMMA: come, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: but, LEXEMA: but, LEMMA: but, MORPHEMA: ConjType=Cmp
# TOKEN: tonight, LEXEMA: tonight, LEMMA: tonight, MORPHEMA: Number=Sing
# TOKEN: because, LEXEMA: because, LEMMA: because, MORPHEMA:
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: what, LEXEMA: what, LEMMA: what, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: did, LEXEMA: did, LEMMA: do, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: on, LEXEMA: on, LEMMA: on, MORPHEMA:
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: date, LEXEMA: date, LEMMA: date, MORPHEMA: Number=Sing
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: election, LEXEMA: election, LEMMA: election, MORPHEMA: Number=Sing
# TOKEN: at, LEXEMA: at, LEMMA: at, MORPHEMA:
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: defining, LEXEMA: defining, LEMMA: define, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: moment, LEXEMA: moment, LEMMA: moment, MORPHEMA: Number=Sing
# TOKEN: change, LEXEMA: change, LEMMA: change, MORPHEMA: Number=Sing
# TOKEN: has, LEXEMA: has, LEMMA: have, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: come, LEXEMA: come, LEMMA: come, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: read, LEXEMA: read, LEMMA: read, MORPHEMA: VerbForm=Inf
# TOKEN: more, LEXEMA: more, LEMMA: more, MORPHEMA: Degree=Cmp
# TOKEN: We, LEXEMA: We, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: did, LEXEMA: did, LEMMA: do, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: n’t, LEXEMA: n’t, LEMMA: not, MORPHEMA:
# TOKEN: start, LEXEMA: start, LEMMA: start, MORPHEMA: VerbForm=Inf
# TOKEN: with, LEXEMA: with, LEMMA: with, MORPHEMA:
# TOKEN: much, LEXEMA: much, LEMMA: much, MORPHEMA: Degree=Pos
# TOKEN: money, LEXEMA: money, LEMMA: money, MORPHEMA: Number=Sing
# TOKEN: or, LEXEMA: or, LEMMA: or, MORPHEMA: ConjType=Cmp
# TOKEN: many, LEXEMA: many, LEMMA: many, MORPHEMA: Degree=Pos
# TOKEN: endorsements, LEXEMA: endorsements, LEMMA: endorsement, MORPHEMA: Number=Plur
# TOKEN: Our, LEXEMA: Our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: campaign, LEXEMA: campaign, LEMMA: campaign, MORPHEMA: Number=Sing
# TOKEN: was, LEXEMA: was, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# TOKEN: not, LEXEMA: not, LEMMA: not, MORPHEMA: Polarity=Neg
# TOKEN: hatched, LEXEMA: hatched, LEMMA: hatch, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: halls, LEXEMA: halls, LEMMA: hall, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Washington, LEXEMA: Washington, LEMMA: Washington, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: began, LEXEMA: began, LEMMA: begin, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: backyards, LEXEMA: backyards, LEMMA: backyard, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Des, LEXEMA: Des, LEMMA: Des, MORPHEMA: Number=Sing
# TOKEN: Moines, LEXEMA: Moines, LEMMA: Moines, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: living, LEXEMA: living, LEMMA: live, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: rooms, LEXEMA: rooms, LEMMA: room, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Concord, LEXEMA: Concord, LEMMA: Concord, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: front, LEXEMA: front, LEMMA: front, MORPHEMA: Degree=Pos
# TOKEN: porches, LEXEMA: porches, LEMMA: porch, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Charleston, LEXEMA: Charleston, LEMMA: Charleston, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: was, LEXEMA: was, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# TOKEN: built, LEXEMA: built, LEMMA: build, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: working, LEXEMA: working, LEMMA: work, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: men, LEXEMA: men, LEMMA: man, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: women, LEXEMA: women, LEMMA: woman, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: dug, LEXEMA: dug, LEMMA: dig, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: into, LEXEMA: into, LEMMA: into, MORPHEMA:
# TOKEN: what, LEXEMA: what, LEMMA: what, MORPHEMA:
# TOKEN: little, LEXEMA: little, LEMMA: little, MORPHEMA: Degree=Pos
# TOKEN: savings, LEXEMA: savings, LEMMA: saving, MORPHEMA: Number=Plur
# TOKEN: they, LEXEMA: they, LEMMA: they, MORPHEMA: Case=Nom|Number=Plur|Person=3|PronType=Prs
# TOKEN: had, LEXEMA: had, LEMMA: have, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: give, LEXEMA: give, LEMMA: give, MORPHEMA: VerbForm=Inf
# TOKEN: $, LEXEMA: $, LEMMA: $, MORPHEMA:
# TOKEN: 5, LEXEMA: 5, LEMMA: 5, MORPHEMA: NumType=Card
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: $, LEXEMA: $, LEMMA: $, MORPHEMA:
# TOKEN: 10, LEXEMA: 10, LEMMA: 10, MORPHEMA: NumType=Card
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: $, LEXEMA: $, LEMMA: $, MORPHEMA:
# TOKEN: 20, LEXEMA: 20, LEMMA: 20, MORPHEMA: NumType=Card
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: cause, LEXEMA: cause, LEMMA: cause, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: grew, LEXEMA: grew, LEMMA: grow, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: strength, LEXEMA: strength, LEMMA: strength, MORPHEMA: Number=Sing
# TOKEN: from, LEXEMA: from, LEMMA: from, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: young, LEXEMA: young, LEMMA: young, MORPHEMA: Degree=Pos
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: rejected, LEXEMA: rejected, LEMMA: reject, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: myth, LEXEMA: myth, LEMMA: myth, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: generation, LEXEMA: generation, LEMMA: generation, MORPHEMA: Number=Sing
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’s, MORPHEMA:
# TOKEN: apathy, LEXEMA: apathy, LEMMA: apathy, MORPHEMA: Degree=Pos
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: left, LEXEMA: left, LEMMA: leave, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: homes, LEXEMA: homes, LEMMA: home, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: families, LEXEMA: families, LEMMA: family, MORPHEMA: Number=Plur
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: jobs, LEXEMA: jobs, LEMMA: job, MORPHEMA: Number=Plur
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: PronType=Rel
# TOKEN: offered, LEXEMA: offered, LEMMA: offer, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: little, LEXEMA: little, LEMMA: little, MORPHEMA: Degree=Pos
# TOKEN: pay, LEXEMA: pay, LEMMA: pay, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: less, LEXEMA: less, LEMMA: less, MORPHEMA: Degree=Cmp
# TOKEN: sleep, LEXEMA: sleep, LEMMA: sleep, MORPHEMA: Number=Sing
# TOKEN: It, LEXEMA: It, LEMMA: it, MORPHEMA: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: drew, LEXEMA: drew, LEMMA: draw, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: strength, LEXEMA: strength, LEMMA: strength, MORPHEMA: Number=Sing
# TOKEN: from, LEXEMA: from, LEMMA: from, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: not, LEXEMA: not, LEMMA: not, MORPHEMA: Polarity=Neg
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: young, LEXEMA: young, LEMMA: young, MORPHEMA: Degree=Pos
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: braved, LEXEMA: braved, LEMMA: brave, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: bitter, LEXEMA: bitter, LEMMA: bitter, MORPHEMA: Degree=Pos
# TOKEN: cold, LEXEMA: cold, LEMMA: cold, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: scorching, LEXEMA: scorching, LEMMA: scorch, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: heat, LEXEMA: heat, LEMMA: heat, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: knock, LEXEMA: knock, LEMMA: knock, MORPHEMA: VerbForm=Inf
# TOKEN: on, LEXEMA: on, LEMMA: on, MORPHEMA:
# TOKEN: doors, LEXEMA: doors, LEMMA: door, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: perfect, LEXEMA: perfect, LEMMA: perfect, MORPHEMA: Degree=Pos
# TOKEN: strangers, LEXEMA: strangers, LEMMA: stranger, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: from, LEXEMA: from, LEMMA: from, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: millions, LEXEMA: millions, LEMMA: million, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Americans, LEXEMA: Americans, LEMMA: Americans, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: volunteered, LEXEMA: volunteered, LEMMA: volunteer, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: organized, LEXEMA: organized, LEMMA: organize, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: proved, LEXEMA: proved, LEMMA: prove, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: more, LEXEMA: more, LEMMA: more, MORPHEMA: Degree=Cmp
# TOKEN: than, LEXEMA: than, LEMMA: than, MORPHEMA:
# TOKEN: two, LEXEMA: two, LEMMA: two, MORPHEMA: NumType=Card
# TOKEN: centuries, LEXEMA: centuries, LEMMA: century, MORPHEMA: Number=Plur
# TOKEN: later, LEXEMA: later, LEMMA: later, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: government, LEXEMA: government, LEMMA: government, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: has, LEXEMA: has, LEMMA: have, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: not, LEXEMA: not, LEMMA: not, MORPHEMA: Polarity=Neg
# TOKEN: perished, LEXEMA: perished, LEMMA: perish, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: from, LEXEMA: from, LEMMA: from, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: Earth, LEXEMA: Earth, LEMMA: Earth, MORPHEMA: Number=Sing
# TOKEN: This, LEXEMA: This, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: your, LEXEMA: your, LEMMA: your, MORPHEMA: Person=2|Poss=Yes|PronType=Prs
# TOKEN: victory, LEXEMA: victory, LEMMA: victory, MORPHEMA: Number=Sing
# TOKEN: And, LEXEMA: And, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: know, LEXEMA: know, LEMMA: know, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Nom|Person=2|PronType=Prs
# TOKEN: did, LEXEMA: did, LEMMA: do, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: n’t, LEXEMA: n’t, LEMMA: not, MORPHEMA:
# TOKEN: do, LEXEMA: do, LEMMA: do, MORPHEMA: VerbForm=Inf
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: just, LEXEMA: just, LEMMA: just, MORPHEMA:
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: win, LEXEMA: win, LEMMA: win, MORPHEMA: VerbForm=Inf
# TOKEN: an, LEXEMA: an, LEMMA: an, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: election, LEXEMA: election, LEMMA: election, MORPHEMA: Number=Sing
# TOKEN: And, LEXEMA: And, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: know, LEXEMA: know, LEMMA: know, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Nom|Person=2|PronType=Prs
# TOKEN: did, LEXEMA: did, LEMMA: do, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: n’t, LEXEMA: n’t, LEMMA: not, MORPHEMA:
# TOKEN: do, LEXEMA: do, LEMMA: do, MORPHEMA: VerbForm=Inf
# TOKEN: it, LEXEMA: it, LEMMA: it, MORPHEMA: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: me, LEXEMA: me, LEMMA: I, MORPHEMA: Case=Acc|Number=Sing|Person=1|PronType=Prs
# TOKEN: You, LEXEMA: You, LEMMA: you, MORPHEMA: Case=Nom|Person=2|PronType=Prs
# TOKEN: did, LEXEMA: did, LEMMA: do, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: it, LEXEMA: it, LEMMA: it, MORPHEMA: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: because, LEXEMA: because, LEMMA: because, MORPHEMA:
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Nom|Person=2|PronType=Prs
# TOKEN: understand, LEXEMA: understand, LEMMA: understand, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: enormity, LEXEMA: enormity, LEMMA: enormity, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: task, LEXEMA: task, LEMMA: task, MORPHEMA: Number=Sing
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: PronType=Rel
# TOKEN: lies, LEXEMA: lies, LEMMA: lie, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: ahead, LEXEMA: ahead, LEMMA: ahead, MORPHEMA:
# TOKEN: For, LEXEMA: For, LEMMA: for, MORPHEMA:
# TOKEN: even, LEXEMA: even, LEMMA: even, MORPHEMA:
# TOKEN: as, LEXEMA: as, LEMMA: as, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: celebrate, LEXEMA: celebrate, LEMMA: celebrate, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: tonight, LEXEMA: tonight, LEMMA: tonight, MORPHEMA: Number=Sing
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: know, LEXEMA: know, LEMMA: know, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: challenges, LEXEMA: challenges, LEMMA: challenge, MORPHEMA: Number=Plur
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: PronType=Rel
# TOKEN: tomorrow, LEXEMA: tomorrow, LEMMA: tomorrow, MORPHEMA: Number=Sing
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: bring, LEXEMA: bring, LEMMA: bring, MORPHEMA: VerbForm=Inf
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: greatest, LEXEMA: greatest, LEMMA: great, MORPHEMA: Degree=Sup
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: lifetime, LEXEMA: lifetime, LEMMA: lifetime, MORPHEMA: Number=Sing
# TOKEN: two, LEXEMA: two, LEMMA: two, MORPHEMA: NumType=Card
# TOKEN: wars, LEXEMA: wars, LEMMA: war, MORPHEMA: Number=Plur
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: planet, LEXEMA: planet, LEMMA: planet, MORPHEMA: Number=Sing
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: peril, LEXEMA: peril, LEMMA: peril, MORPHEMA: Number=Sing
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: worst, LEXEMA: worst, LEMMA: bad, MORPHEMA: Degree=Sup
# TOKEN: financial, LEXEMA: financial, LEMMA: financial, MORPHEMA: Degree=Pos
# TOKEN: crisis, LEXEMA: crisis, LEMMA: crisis, MORPHEMA: Number=Sing
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: century, LEXEMA: century, LEMMA: century, MORPHEMA: Number=Sing
# TOKEN: Even, LEXEMA: Even, LEMMA: even, MORPHEMA:
# TOKEN: as, LEXEMA: as, LEMMA: as, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: stand, LEXEMA: stand, LEMMA: stand, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: here, LEXEMA: here, LEMMA: here, MORPHEMA: PronType=Dem
# TOKEN: tonight, LEXEMA: tonight, LEMMA: tonight, MORPHEMA: Number=Sing
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: know, LEXEMA: know, LEMMA: know, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA:
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: brave, LEXEMA: brave, LEMMA: brave, MORPHEMA: Degree=Pos
# TOKEN: Americans, LEXEMA: Americans, LEMMA: Americans, MORPHEMA: Number=Plur
# TOKEN: waking, LEXEMA: waking, LEMMA: wake, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: up, LEXEMA: up, LEMMA: up, MORPHEMA:
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: deserts, LEXEMA: deserts, LEMMA: desert, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Iraq, LEXEMA: Iraq, LEMMA: Iraq, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: mountains, LEXEMA: mountains, LEMMA: mountain, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: Afghanistan, LEXEMA: Afghanistan, LEMMA: Afghanistan, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: risk, LEXEMA: risk, LEMMA: risk, MORPHEMA: VerbForm=Inf
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: lives, LEXEMA: lives, LEMMA: life, MORPHEMA: Number=Plur
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: us, LEXEMA: us, LEMMA: we, MORPHEMA: Case=Acc|Number=Plur|Person=1|PronType=Prs
# TOKEN: There, LEXEMA: There, LEMMA: there, MORPHEMA:
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: mothers, LEXEMA: mothers, LEMMA: mother, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: fathers, LEXEMA: fathers, LEMMA: father, MORPHEMA: Number=Plur
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: lie, LEXEMA: lie, LEMMA: lie, MORPHEMA: VerbForm=Inf
# TOKEN: awake, LEXEMA: awake, LEMMA: awake, MORPHEMA: Degree=Pos
# TOKEN: after, LEXEMA: after, LEMMA: after, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: children, LEXEMA: children, LEMMA: child, MORPHEMA: Number=Plur
# TOKEN: fall, LEXEMA: fall, LEMMA: fall, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: asleep, LEXEMA: asleep, LEMMA: asleep, MORPHEMA: Degree=Pos
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: wonder, LEXEMA: wonder, LEMMA: wonder, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: how, LEXEMA: how, LEMMA: how, MORPHEMA:
# TOKEN: they, LEXEMA: they, LEMMA: they, MORPHEMA: Case=Nom|Number=Plur|Person=3|PronType=Prs
# TOKEN: ’ll, LEXEMA: ’ll, LEMMA: ’ll, MORPHEMA: VerbType=Mod
# TOKEN: make, LEXEMA: make, LEMMA: make, MORPHEMA: VerbForm=Inf
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: mortgage, LEXEMA: mortgage, LEMMA: mortgage, MORPHEMA: Number=Sing
# TOKEN: or, LEXEMA: or, LEMMA: or, MORPHEMA: ConjType=Cmp
# TOKEN: pay, LEXEMA: pay, LEMMA: pay, MORPHEMA: VerbForm=Inf
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: doctors, LEXEMA: doctors, LEMMA: doctor, MORPHEMA: Number=Plur
# TOKEN: bills, LEXEMA: bills, LEMMA: bill, MORPHEMA: Number=Plur
# TOKEN: or, LEXEMA: or, LEMMA: or, MORPHEMA: ConjType=Cmp
# TOKEN: save, LEXEMA: save, LEMMA: save, MORPHEMA: VerbForm=Inf
# TOKEN: enough, LEXEMA: enough, LEMMA: enough, MORPHEMA: Degree=Pos
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: their, LEXEMA: their, LEMMA: their, MORPHEMA: Number=Plur|Person=3|Poss=Yes|PronType=Prs
# TOKEN: child, LEXEMA: child, LEMMA: child, MORPHEMA: Number=Sing
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’s, MORPHEMA:
# TOKEN: college, LEXEMA: college, LEMMA: college, MORPHEMA: Number=Sing
# TOKEN: education, LEXEMA: education, LEMMA: education, MORPHEMA: Number=Sing
# TOKEN: There, LEXEMA: There, LEMMA: there, MORPHEMA:
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: new, LEXEMA: new, LEMMA: new, MORPHEMA: Degree=Pos
# TOKEN: energy, LEXEMA: energy, LEMMA: energy, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: harness, LEXEMA: harness, LEMMA: harness, MORPHEMA: Number=Sing
# TOKEN: new, LEXEMA: new, LEMMA: new, MORPHEMA: Degree=Pos
# TOKEN: jobs, LEXEMA: jobs, LEMMA: job, MORPHEMA: Number=Plur
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: created, LEXEMA: created, LEMMA: create, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: new, LEXEMA: new, LEMMA: new, MORPHEMA: Degree=Pos
# TOKEN: schools, LEXEMA: schools, LEMMA: school, MORPHEMA: Number=Plur
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: build, LEXEMA: build, LEMMA: build, MORPHEMA: VerbForm=Inf
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: threats, LEXEMA: threats, LEMMA: threat, MORPHEMA: Number=Plur
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: meet, LEXEMA: meet, LEMMA: meet, MORPHEMA: VerbForm=Inf
# TOKEN: alliances, LEXEMA: alliances, LEMMA: alliance, MORPHEMA: Number=Plur
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: repair, LEXEMA: repair, LEMMA: repair, MORPHEMA: VerbForm=Inf
# TOKEN: The, LEXEMA: The, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: road, LEXEMA: road, LEMMA: road, MORPHEMA: Number=Sing
# TOKEN: ahead, LEXEMA: ahead, LEMMA: ahead, MORPHEMA:
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: long, LEXEMA: long, LEMMA: long, MORPHEMA: Degree=Pos
# TOKEN: Our, LEXEMA: Our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: climb, LEXEMA: climb, LEMMA: climb, MORPHEMA: Number=Sing
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: steep, LEXEMA: steep, LEMMA: steep, MORPHEMA: Degree=Pos
# TOKEN: We, LEXEMA: We, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: may, LEXEMA: may, LEMMA: may, MORPHEMA: VerbForm=Fin
# TOKEN: not, LEXEMA: not, LEMMA: not, MORPHEMA: Polarity=Neg
# TOKEN: get, LEXEMA: get, LEMMA: get, MORPHEMA: VerbForm=Inf
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA: PronType=Dem
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: one, LEXEMA: one, LEMMA: one, MORPHEMA: NumType=Card
# TOKEN: year, LEXEMA: year, LEMMA: year, MORPHEMA: Number=Sing
# TOKEN: or, LEXEMA: or, LEMMA: or, MORPHEMA: ConjType=Cmp
# TOKEN: even, LEXEMA: even, LEMMA: even, MORPHEMA:
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: one, LEXEMA: one, LEMMA: one, MORPHEMA: NumType=Card
# TOKEN: term, LEXEMA: term, LEMMA: term, MORPHEMA: Number=Sing
# TOKEN: But, LEXEMA: But, LEMMA: but, MORPHEMA: ConjType=Cmp
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: have, LEXEMA: have, LEMMA: have, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: never, LEXEMA: never, LEMMA: never, MORPHEMA:
# TOKEN: been, LEXEMA: been, LEMMA: be, MORPHEMA: Tense=Past|VerbForm=Part
# TOKEN: more, LEXEMA: more, LEMMA: more, MORPHEMA: Degree=Cmp
# TOKEN: hopeful, LEXEMA: hopeful, LEMMA: hopeful, MORPHEMA: Degree=Pos
# TOKEN: than, LEXEMA: than, LEMMA: than, MORPHEMA:
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: am, LEXEMA: am, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin
# TOKEN: tonight, LEXEMA: tonight, LEMMA: tonight, MORPHEMA: Number=Sing
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: get, LEXEMA: get, LEMMA: get, MORPHEMA: VerbForm=Inf
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA: PronType=Dem
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: promise, LEXEMA: promise, LEMMA: promise, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Acc|Person=2|PronType=Prs
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: as, LEXEMA: as, LEMMA: as, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: get, LEXEMA: get, LEMMA: get, MORPHEMA: VerbForm=Inf
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA: PronType=Dem
# TOKEN: There, LEXEMA: There, LEMMA: there, MORPHEMA:
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: setbacks, LEXEMA: setbacks, LEMMA: setback, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: false, LEXEMA: false, LEMMA: false, MORPHEMA: Degree=Pos
# TOKEN: starts, LEXEMA: starts, LEMMA: start, MORPHEMA: Number=Plur
# TOKEN: There, LEXEMA: There, LEMMA: there, MORPHEMA:
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: many, LEXEMA: many, LEMMA: many, MORPHEMA: Degree=Pos
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: wo, LEXEMA: wo, LEMMA: will, MORPHEMA: VerbType=Mod
# TOKEN: n’t, LEXEMA: n’t, LEMMA: not, MORPHEMA:
# TOKEN: agree, LEXEMA: agree, LEMMA: agree, MORPHEMA: VerbForm=Inf
# TOKEN: with, LEXEMA: with, LEMMA: with, MORPHEMA:
# TOKEN: every, LEXEMA: every, LEMMA: every, MORPHEMA:
# TOKEN: decision, LEXEMA: decision, LEMMA: decision, MORPHEMA: Number=Sing
# TOKEN: or, LEXEMA: or, LEMMA: or, MORPHEMA: ConjType=Cmp
# TOKEN: policy, LEXEMA: policy, LEMMA: policy, MORPHEMA: Number=Sing
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: make, LEXEMA: make, LEMMA: make, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: as, LEXEMA: as, LEMMA: as, MORPHEMA:
# TOKEN: president, LEXEMA: president, LEMMA: president, MORPHEMA: Number=Sing
# TOKEN: And, LEXEMA: And, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: know, LEXEMA: know, LEMMA: know, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: government, LEXEMA: government, LEMMA: government, MORPHEMA: Number=Sing
# TOKEN: ca, LEXEMA: ca, LEMMA: can, MORPHEMA: VerbType=Mod
# TOKEN: n’t, LEXEMA: n’t, LEMMA: not, MORPHEMA:
# TOKEN: solve, LEXEMA: solve, LEMMA: solve, MORPHEMA: VerbForm=Inf
# TOKEN: every, LEXEMA: every, LEMMA: every, MORPHEMA:
# TOKEN: problem, LEXEMA: problem, LEMMA: problem, MORPHEMA: Number=Sing
# TOKEN: But, LEXEMA: But, LEMMA: but, MORPHEMA: ConjType=Cmp
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: always, LEXEMA: always, LEMMA: always, MORPHEMA:
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: honest, LEXEMA: honest, LEMMA: honest, MORPHEMA: Degree=Pos
# TOKEN: with, LEXEMA: with, LEMMA: with, MORPHEMA:
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Acc|Person=2|PronType=Prs
# TOKEN: about, LEXEMA: about, LEMMA: about, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: challenges, LEXEMA: challenges, LEMMA: challenge, MORPHEMA: Number=Plur
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: face, LEXEMA: face, LEMMA: face, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: listen, LEXEMA: listen, LEMMA: listen, MORPHEMA: VerbForm=Inf
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Acc|Person=2|PronType=Prs
# TOKEN: especially, LEXEMA: especially, LEMMA: especially, MORPHEMA:
# TOKEN: when, LEXEMA: when, LEMMA: when, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: disagree, LEXEMA: disagree, LEMMA: disagree, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: And, LEXEMA: And, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: above, LEXEMA: above, LEMMA: above, MORPHEMA:
# TOKEN: all, LEXEMA: all, LEMMA: all, MORPHEMA:
# TOKEN: I, LEXEMA: I, LEMMA: I, MORPHEMA: Case=Nom|Number=Sing|Person=1|PronType=Prs
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: ask, LEXEMA: ask, LEMMA: ask, MORPHEMA: VerbForm=Inf
# TOKEN: you, LEXEMA: you, LEMMA: you, MORPHEMA: Case=Acc|Person=2|PronType=Prs
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: join, LEXEMA: join, LEMMA: join, MORPHEMA: VerbForm=Inf
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: work, LEXEMA: work, LEMMA: work, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: remaking, LEXEMA: remaking, LEMMA: remake, MORPHEMA: Aspect=Prog|Tense=Pres|VerbForm=Part
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: nation, LEXEMA: nation, LEMMA: nation, MORPHEMA: Number=Sing
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: only, LEXEMA: only, LEMMA: only, MORPHEMA: Degree=Pos
# TOKEN: way, LEXEMA: way, LEMMA: way, MORPHEMA: Number=Sing
# TOKEN: it, LEXEMA: it, LEMMA: it, MORPHEMA: Gender=Neut|Number=Sing|Person=3|PronType=Prs
# TOKEN: ’s, LEXEMA: ’s, LEMMA: ’s, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: been, LEXEMA: been, LEMMA: be, MORPHEMA: Tense=Past|VerbForm=Part
# TOKEN: done, LEXEMA: done, LEMMA: do, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: 221, LEXEMA: 221, LEMMA: 221, MORPHEMA: NumType=Card
# TOKEN: years, LEXEMA: years, LEMMA: year, MORPHEMA: Number=Plur
# TOKEN: block, LEXEMA: block, LEMMA: block, MORPHEMA: Number=Sing
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: block, LEXEMA: block, LEMMA: block, MORPHEMA: Number=Sing
# TOKEN: brick, LEXEMA: brick, LEMMA: brick, MORPHEMA: Number=Sing
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: brick, LEXEMA: brick, LEMMA: brick, MORPHEMA: Number=Sing
# TOKEN: calloused, LEXEMA: calloused, LEMMA: calloused, MORPHEMA: Degree=Pos
# TOKEN: hand, LEXEMA: hand, LEMMA: hand, MORPHEMA: Number=Sing
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: calloused, LEXEMA: calloused, LEMMA: calloused, MORPHEMA: Degree=Pos
# TOKEN: hand, LEXEMA: hand, LEMMA: hand, MORPHEMA: Number=Sing
# TOKEN: What, LEXEMA: What, LEMMA: what, MORPHEMA:
# TOKEN: began, LEXEMA: began, LEMMA: begin, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: 21, LEXEMA: 21, LEMMA: 21, MORPHEMA: NumType=Card
# TOKEN: months, LEXEMA: months, LEMMA: month, MORPHEMA: Number=Plur
# TOKEN: ago, LEXEMA: ago, LEMMA: ago, MORPHEMA:
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# ...
# TOKEN: from, LEXEMA: from, LEMMA: from, MORPHEMA:
# TOKEN: Atlanta, LEXEMA: Atlanta, LEMMA: Atlanta, MORPHEMA: Number=Sing
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: told, LEXEMA: told, LEMMA: tell, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: We, LEXEMA: We, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: Shall, LEXEMA: Shall, LEMMA: shall, MORPHEMA: VerbType=Mod
# TOKEN: Overcome, LEXEMA: Overcome, LEMMA: overcome, MORPHEMA: VerbForm=Inf
# TOKEN: Yes, LEXEMA: Yes, LEMMA: yes, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: can, LEXEMA: can, LEMMA: can, MORPHEMA: VerbForm=Fin
# TOKEN: A, LEXEMA: A, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: man, LEXEMA: man, LEMMA: man, MORPHEMA: Number=Sing
# TOKEN: touched, LEXEMA: touched, LEMMA: touch, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: down, LEXEMA: down, LEMMA: down, MORPHEMA:
# TOKEN: on, LEXEMA: on, LEMMA: on, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: moon, LEXEMA: moon, LEMMA: moon, MORPHEMA: Number=Sing
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: wall, LEXEMA: wall, LEMMA: wall, MORPHEMA: Number=Sing
# TOKEN: came, LEXEMA: came, LEMMA: come, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: down, LEXEMA: down, LEMMA: down, MORPHEMA:
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: Berlin, LEXEMA: Berlin, LEMMA: Berlin, MORPHEMA: Number=Sing
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: world, LEXEMA: world, LEMMA: world, MORPHEMA: Number=Sing
# TOKEN: was, LEXEMA: was, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# TOKEN: connected, LEXEMA: connected, LEMMA: connect, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: by, LEXEMA: by, LEMMA: by, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: own, LEXEMA: own, LEMMA: own, MORPHEMA: Degree=Pos
# TOKEN: science, LEXEMA: science, LEMMA: science, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: imagination, LEXEMA: imagination, LEMMA: imagination, MORPHEMA: Number=Sing
# TOKEN: And, LEXEMA: And, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: year, LEXEMA: year, LEMMA: year, MORPHEMA: Number=Sing
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: this, LEXEMA: this, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: election, LEXEMA: election, LEMMA: election, MORPHEMA: Number=Sing
# TOKEN: she, LEXEMA: she, LEMMA: she, MORPHEMA: Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# TOKEN: touched, LEXEMA: touched, LEMMA: touch, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: her, LEXEMA: her, LEMMA: her, MORPHEMA: Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# TOKEN: finger, LEXEMA: finger, LEMMA: finger, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: screen, LEXEMA: screen, LEMMA: screen, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: cast, LEXEMA: cast, LEMMA: cast, MORPHEMA: Tense=Past|VerbForm=Fin
# TOKEN: her, LEXEMA: her, LEMMA: her, MORPHEMA: Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# TOKEN: vote, LEXEMA: vote, LEMMA: vote, MORPHEMA: Number=Sing
# TOKEN: because, LEXEMA: because, LEMMA: because, MORPHEMA:
# TOKEN: after, LEXEMA: after, LEMMA: after, MORPHEMA:
# TOKEN: 106, LEXEMA: 106, LEMMA: 106, MORPHEMA: NumType=Card
# TOKEN: years, LEXEMA: years, LEMMA: year, MORPHEMA: Number=Plur
# TOKEN: in, LEXEMA: in, LEMMA: in, MORPHEMA:
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: through, LEXEMA: through, LEMMA: through, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: best, LEXEMA: best, LEMMA: good, MORPHEMA: Degree=Sup
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: times, LEXEMA: times, LEMMA: time, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: darkest, LEXEMA: darkest, LEMMA: darkest, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: hours, LEXEMA: hours, LEMMA: hour, MORPHEMA: Number=Plur
# TOKEN: she, LEXEMA: she, LEMMA: she, MORPHEMA: Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# TOKEN: knows, LEXEMA: knows, LEMMA: know, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: how, LEXEMA: how, LEMMA: how, MORPHEMA:
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: can, LEXEMA: can, LEMMA: can, MORPHEMA: VerbForm=Fin
# TOKEN: change, LEXEMA: change, LEMMA: change, MORPHEMA: VerbForm=Inf
# TOKEN: Yes, LEXEMA: Yes, LEMMA: yes, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: can, LEXEMA: can, LEMMA: can, MORPHEMA: VerbForm=Fin
# TOKEN: America, LEXEMA: America, LEMMA: America, MORPHEMA: Number=Sing
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: have, LEXEMA: have, LEMMA: have, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: come, LEXEMA: come, LEMMA: come, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: far, LEXEMA: far, LEMMA: far, MORPHEMA:
# TOKEN: We, LEXEMA: We, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: have, LEXEMA: have, LEMMA: have, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: seen, LEXEMA: seen, LEMMA: see, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: much, LEXEMA: much, LEMMA: much, MORPHEMA: Degree=Pos
# TOKEN: But, LEXEMA: But, LEMMA: but, MORPHEMA: ConjType=Cmp
# TOKEN: there, LEXEMA: there, LEMMA: there, MORPHEMA:
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: much, LEXEMA: much, LEMMA: much, MORPHEMA:
# TOKEN: more, LEXEMA: more, LEMMA: more, MORPHEMA: Degree=Cmp
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: do, LEXEMA: do, LEMMA: do, MORPHEMA: VerbForm=Inf
# TOKEN: So, LEXEMA: So, LEMMA: so, MORPHEMA:
# TOKEN: tonight, LEXEMA: tonight, LEMMA: tonight, MORPHEMA: Number=Sing
# TOKEN: let, LEXEMA: let, LEMMA: let, MORPHEMA: VerbForm=Inf
# TOKEN: us, LEXEMA: us, LEMMA: we, MORPHEMA: Case=Acc|Number=Plur|Person=1|PronType=Prs
# TOKEN: ask, LEXEMA: ask, LEMMA: ask, MORPHEMA: VerbForm=Inf
# TOKEN: ourselves, LEXEMA: ourselves, LEMMA: ourselves, MORPHEMA: Case=Acc|Number=Plur|Person=1|PronType=Prs|Reflex=Yes
# TOKEN: if, LEXEMA: if, LEMMA: if, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: children, LEXEMA: children, LEMMA: child, MORPHEMA: Number=Plur
# TOKEN: should, LEXEMA: should, LEMMA: should, MORPHEMA: VerbForm=Fin
# TOKEN: live, LEXEMA: live, LEMMA: live, MORPHEMA: VerbForm=Inf
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: see, LEXEMA: see, LEMMA: see, MORPHEMA: VerbForm=Inf
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: next, LEXEMA: next, LEMMA: next, MORPHEMA: Degree=Pos
# TOKEN: century, LEXEMA: century, LEMMA: century, MORPHEMA: Number=Sing
# TOKEN: if, LEXEMA: if, LEMMA: if, MORPHEMA:
# TOKEN: my, LEXEMA: my, LEMMA: my, MORPHEMA: Number=Sing|Person=1|Poss=Yes|PronType=Prs
# TOKEN: daughters, LEXEMA: daughters, LEMMA: daughter, MORPHEMA: Number=Plur
# TOKEN: should, LEXEMA: should, LEMMA: should, MORPHEMA: VerbForm=Fin
# TOKEN: be, LEXEMA: be, LEMMA: be, MORPHEMA: VerbForm=Inf
# TOKEN: so, LEXEMA: so, LEMMA: so, MORPHEMA:
# TOKEN: lucky, LEXEMA: lucky, LEMMA: lucky, MORPHEMA: Degree=Pos
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: live, LEXEMA: live, LEMMA: live, MORPHEMA: VerbForm=Inf
# TOKEN: as, LEXEMA: as, LEMMA: as, MORPHEMA:
# TOKEN: long, LEXEMA: long, LEMMA: long, MORPHEMA:
# TOKEN: as, LEXEMA: as, LEMMA: as, MORPHEMA:
# TOKEN: Ann, LEXEMA: Ann, LEMMA: Ann, MORPHEMA: Number=Sing
# TOKEN: Nixon, LEXEMA: Nixon, LEMMA: Nixon, MORPHEMA: Number=Sing
# TOKEN: Cooper, LEXEMA: Cooper, LEMMA: Cooper, MORPHEMA: Number=Sing
# TOKEN: what, LEXEMA: what, LEMMA: what, MORPHEMA:
# TOKEN: change, LEXEMA: change, LEMMA: change, MORPHEMA: Number=Sing
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: they, LEXEMA: they, LEMMA: they, MORPHEMA: Case=Nom|Number=Plur|Person=3|PronType=Prs
# TOKEN: see, LEXEMA: see, LEMMA: see, MORPHEMA: VerbForm=Inf
# TOKEN: What, LEXEMA: What, LEMMA: what, MORPHEMA:
# TOKEN: progress, LEXEMA: progress, LEMMA: progress, MORPHEMA: Number=Sing
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: have, LEXEMA: have, LEMMA: have, MORPHEMA: VerbForm=Inf
# TOKEN: made, LEXEMA: made, LEMMA: make, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: This, LEXEMA: This, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: chance, LEXEMA: chance, LEMMA: chance, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: answer, LEXEMA: answer, LEMMA: answer, MORPHEMA: VerbForm=Inf
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: call, LEXEMA: call, LEMMA: call, MORPHEMA: Number=Sing
# TOKEN: This, LEXEMA: This, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: moment, LEXEMA: moment, LEMMA: moment, MORPHEMA: Number=Sing
# TOKEN: This, LEXEMA: This, LEMMA: this, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: is, LEXEMA: is, LEMMA: be, MORPHEMA: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: time, LEXEMA: time, LEMMA: time, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: put, LEXEMA: put, LEMMA: put, MORPHEMA: VerbForm=Inf
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: back, LEXEMA: back, LEMMA: back, MORPHEMA:
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: work, LEXEMA: work, LEMMA: work, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: open, LEXEMA: open, LEMMA: open, MORPHEMA: Degree=Pos
# TOKEN: doors, LEXEMA: doors, LEMMA: door, MORPHEMA: Number=Plur
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: opportunity, LEXEMA: opportunity, LEMMA: opportunity, MORPHEMA: Number=Sing
# TOKEN: for, LEXEMA: for, LEMMA: for, MORPHEMA:
# TOKEN: our, LEXEMA: our, LEMMA: our, MORPHEMA: Number=Plur|Person=1|Poss=Yes|PronType=Prs
# TOKEN: kids, LEXEMA: kids, LEMMA: kid, MORPHEMA: Number=Plur
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: restore, LEXEMA: restore, LEMMA: restore, MORPHEMA: VerbForm=Inf
# TOKEN: prosperity, LEXEMA: prosperity, LEMMA: prosperity, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: promote, LEXEMA: promote, LEMMA: promote, MORPHEMA: VerbForm=Inf
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: cause, LEXEMA: cause, LEMMA: cause, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: peace, LEXEMA: peace, LEMMA: peace, MORPHEMA: Number=Sing
# TOKEN: to, LEXEMA: to, LEMMA: to, MORPHEMA:
# TOKEN: reclaim, LEXEMA: reclaim, LEMMA: reclaim, MORPHEMA: VerbForm=Inf
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: American, LEXEMA: American, LEMMA: american, MORPHEMA: Degree=Pos
# TOKEN: dream, LEXEMA: dream, LEMMA: dream, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: reaffirm, LEXEMA: reaffirm, LEMMA: reaffirm, MORPHEMA: VerbForm=Inf
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: fundamental, LEXEMA: fundamental, LEMMA: fundamental, MORPHEMA: Degree=Pos
# TOKEN: truth, LEXEMA: truth, LEMMA: truth, MORPHEMA: Number=Sing
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: out, LEXEMA: out, LEMMA: out, MORPHEMA:
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: many, LEXEMA: many, LEMMA: many, MORPHEMA: Degree=Pos
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: one, LEXEMA: one, LEMMA: one, MORPHEMA: NumType=Card
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: while, LEXEMA: while, LEMMA: while, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: breathe, LEXEMA: breathe, LEMMA: breathe, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: hope, LEXEMA: hope, LEMMA: hope, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: And, LEXEMA: And, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: where, LEXEMA: where, LEMMA: where, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: are, LEXEMA: are, LEMMA: be, MORPHEMA: Mood=Ind|Tense=Pres|VerbForm=Fin
# TOKEN: met, LEXEMA: met, LEMMA: meet, MORPHEMA: Aspect=Perf|Tense=Past|VerbForm=Part
# TOKEN: with, LEXEMA: with, LEMMA: with, MORPHEMA:
# TOKEN: cynicism, LEXEMA: cynicism, LEMMA: cynicism, MORPHEMA: Number=Sing
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: doubts, LEXEMA: doubts, LEMMA: doubt, MORPHEMA: Number=Plur
# TOKEN: and, LEXEMA: and, LEMMA: and, MORPHEMA: ConjType=Cmp
# TOKEN: those, LEXEMA: those, LEMMA: those, MORPHEMA: Number=Plur|PronType=Dem
# TOKEN: who, LEXEMA: who, LEMMA: who, MORPHEMA:
# TOKEN: tell, LEXEMA: tell, LEMMA: tell, MORPHEMA: Tense=Pres|VerbForm=Fin
# TOKEN: us, LEXEMA: us, LEMMA: we, MORPHEMA: Case=Acc|Number=Plur|Person=1|PronType=Prs
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: ca, LEXEMA: ca, LEMMA: can, MORPHEMA: VerbType=Mod
# TOKEN: n’t, LEXEMA: n’t, LEMMA: not, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: will, LEXEMA: will, LEMMA: will, MORPHEMA: VerbForm=Fin
# TOKEN: respond, LEXEMA: respond, LEMMA: respond, MORPHEMA: VerbForm=Inf
# TOKEN: with, LEXEMA: with, LEMMA: with, MORPHEMA:
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: Number=Sing|PronType=Dem
# TOKEN: timeless, LEXEMA: timeless, LEMMA: timeless, MORPHEMA: Number=Sing
# TOKEN: creed, LEXEMA: creed, LEMMA: creed, MORPHEMA: Number=Sing
# TOKEN: that, LEXEMA: that, LEMMA: that, MORPHEMA: PronType=Rel
# TOKEN: sums, LEXEMA: sums, LEMMA: sum, MORPHEMA: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# TOKEN: up, LEXEMA: up, LEMMA: up, MORPHEMA:
# TOKEN: the, LEXEMA: the, LEMMA: the, MORPHEMA: Definite=Def|PronType=Art
# TOKEN: spirit, LEXEMA: spirit, LEMMA: spirit, MORPHEMA: Number=Sing
# TOKEN: of, LEXEMA: of, LEMMA: of, MORPHEMA:
# TOKEN: a, LEXEMA: a, LEMMA: a, MORPHEMA: Definite=Ind|PronType=Art
# TOKEN: people, LEXEMA: people, LEMMA: people, MORPHEMA: Number=Plur
# TOKEN: Yes, LEXEMA: Yes, LEMMA: yes, MORPHEMA:
# TOKEN: we, LEXEMA: we, LEMMA: we, MORPHEMA: Case=Nom|Number=Plur|Person=1|PronType=Prs
# TOKEN: can, LEXEMA: can, LEMMA: can, MORPHEMA: VerbForm=Fin

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# Podemos extraer información sobre las palabras del documento, por medio de los siguientes atributos:
#
# ```token.lemma_``` extrae el lema de cada token
#
# ```token.lex.text``` extrae el lexema de cada token
#
# ```token.morph``` extrae el morfema de cada token
#
# Es importante mencionar que sPaCy no tiene en la clase Doc un atributo para encontrar un lexema tal y como se haría en un análisis sintáctico.
#
# token.morph devuelve el número, persona, tiempo y forma de verbo de cada token.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 5.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes identificar/eliminar las stop words?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# Primero, SpaCy tiene un set de palabras ya establecidas como stop words, la cual se puede acceder con el atributo token.is_stop
# Ahora, vamos a identificar cuantas stop words hay en el doc
stopword_count = 0
for token in doc:
    if not token.is_stop:
        stopword_count += 1
print(f"El total de stop words en el texto es de {stopword_count} palabras. ") # total de palabras que no son stopwords
text_without_stopwords = ' '.join([token.text for token in doc if not token.is_stop])
print(f"El texto sin stopwords es: {text_without_stopwords}")
# Out:
# El total de stop words en el texto es de 906 palabras.
# El texto sin stopwords es: “ Hello , Chicago .
#  doubts America place things possible , wonders dream founders alive time , questions power democracy , tonight answer .
#  answer told lines stretched schools churches numbers nation seen , people waited hours hours , time lives , believed time different , voices difference .
#  answer spoken young old , rich poor , Democrat Republican , black , white , Hispanic , Asian , Native American , gay , straight , disabled disabled . Americans sent message world collection individuals collection red states blue states .
#  , , United States America .
#  answer led told long cynical fearful doubtful achieve hands arc history bend hope better day .
#  long time coming , tonight , date election defining moment change come America .
#  [ read ]
#
#  start money endorsements . campaign hatched halls Washington . began backyards Des Moines living rooms Concord porches Charleston . built working men women dug little savings $ 5 $ 10 $ 20 cause .
#  grew strength young people rejected myth generation apathy left homes families jobs offered little pay sleep .
#  drew strength - - young people braved bitter cold scorching heat knock doors perfect strangers , millions Americans volunteered organized proved centuries later government people , people , people perished Earth .
#  victory .
#  know win election . know .
#  understand enormity task lies ahead . celebrate tonight , know challenges tomorrow bring greatest lifetime — wars , planet peril , worst financial crisis century .
#  stand tonight , know brave Americans waking deserts Iraq mountains Afghanistan risk lives .
#  mothers fathers lie awake children fall asleep wonder mortgage pay doctors ’ bills save child college education .
#  new energy harness , new jobs created , new schools build , threats meet , alliances repair .
#  road ahead long . climb steep . year term . , America , hopeful tonight .
#  promise , people .
#  setbacks false starts . wo agree decision policy president . know government solve problem .
#  honest challenges face . listen , especially disagree . , , ask join work remaking nation , way America 221 years — block block , brick brick , calloused hand calloused hand .
#  began 21 months ago depths winter end autumn night .
#  victory change seek . chance change . happen way things .
#  happen , new spirit service , new spirit sacrifice .
#  let summon new spirit patriotism , responsibility , resolves pitch work harder look .
#  Let remember , financial crisis taught , thriving Wall Street Main Street suffers .
#  country , rise fall nation , people . Let resist temptation fall partisanship pettiness immaturity poisoned politics long .
#  Let remember man state carried banner Republican Party White House , party founded values self - reliance individual liberty national unity .
#  values share . Democratic Party won great victory tonight , measure humility determination heal divides held progress .
#  Lincoln said nation far divided , enemies friends . passion strained , break bonds affection .
#  Americans support earn , won vote tonight , hear voices . need help . president , .
#  watching tonight shores , parliaments palaces , huddled radios forgotten corners world , stories singular , destiny shared , new dawn American leadership hand .
#  — tear world : defeat . seek peace security : support . wondered America beacon burns bright : Tonight proved true strength nation comes arms scale wealth , enduring power ideals : democracy , liberty , opportunity unyielding hope .
#  true genius America : America change . union perfected . achieved gives hope achieve tomorrow .
#  election firsts stories told generations . mind tonight woman cast ballot Atlanta . lot like millions stood line voice heard election thing : Ann Nixon Cooper 106 years old .
#  born generation past slavery ; time cars road planes sky ; like vote reasons — woman color skin .
#  tonight , think seen century America — heartache hope ; struggle progress ; times told , people pressed American creed : Yes .
#  time women voices silenced hopes dismissed , lived stand speak reach ballot . Yes .
#  despair dust bowl depression land , saw nation conquer fear New Deal , new jobs , new sense common purpose . Yes .
#  bombs fell harbor tyranny threatened world , witness generation rise greatness democracy saved . Yes .
#  buses Montgomery , hoses Birmingham , bridge Selma , preacher Atlanta told people “ Shall Overcome . ” Yes .
#  man touched moon , wall came Berlin , world connected science imagination .
#  year , election , touched finger screen , cast vote , 106 years America , best times darkest hours , knows America change .
#  Yes .
#  America , come far . seen . . tonight , let ask — children live century ; daughters lucky live long Ann Nixon Cooper , change ? progress ?
#  chance answer . moment .
#  time , people work open doors opportunity kids ; restore prosperity promote cause peace ; reclaim American dream reaffirm fundamental truth , , , ; breathe , hope . met cynicism doubts tell , respond timeless creed sums spirit people : Yes , . [

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
#
# El atributo .is_stop indica si el token es una stop word, y el atributo .text contiene el texto del token. Para contar las stop words, se usa un ciclo for para recorrer todas las palabras del documento. Luego, se puede filtrar el texto original del documento con el atributo .is_stop y .text sobre todo el documento y uniendo luego con la función join.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 6.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué atributo del token contiene la etiqueta NER?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# El atributo que contiene entidades es el .ents del documento de sPaCy doc
entity_counter = 0
for ent in doc.ents:
    print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    entity_counter += 1
print(f'El total de entidades mostradas en el texto es de: {entity_counter}')
# Out:
# Chicago - GPE - Countries, cities, states
# America - GPE - Countries, cities, states
# tonight - TIME - Times smaller than a day
# three hours - TIME - Times smaller than a day
# four hours - TIME - Times smaller than a day
# first - ORDINAL - "first", "second", etc.
# Democrat - NORP - Nationalities or religious or political groups
# Republican - NORP - Nationalities or religious or political groups
# Hispanic - NORP - Nationalities or religious or political groups
# Asian - NORP - Nationalities or religious or political groups
# Native American - NORP - Nationalities or religious or political groups
# Americans - NORP - Nationalities or religious or political groups
# the United States of America - GPE - Countries, cities, states
# tonight - TIME - Times smaller than a day
# America - GPE - Countries, cities, states
# Washington - GPE - Countries, cities, states
# Des Moines - GPE - Countries, cities, states
# Concord - GPE - Countries, cities, states
# Charleston - GPE - Countries, cities, states
# $5 and $10 and $20 - MONEY - Monetary values, including unit
# millions - CARDINAL - Numerals that do not fall under another type
# Americans - NORP - Nationalities or religious or political groups
# more than two centuries later - DATE - Absolute or relative dates or periods
# Earth - LOC - Non-GPE locations, mountain ranges, bodies of water
# tonight - TIME - Times smaller than a day
# tomorrow - DATE - Absolute or relative dates or periods
# two - CARDINAL - Numerals that do not fall under another type
# a century - DATE - Absolute or relative dates or periods
# tonight - TIME - Times smaller than a day
# Americans - NORP - Nationalities or religious or political groups
# Iraq - GPE - Countries, cities, states
# Afghanistan - GPE - Countries, cities, states
# one year - DATE - Absolute or relative dates or periods
# one - CARDINAL - Numerals that do not fall under another type
# America - GPE - Countries, cities, states
# tonight - TIME - Times smaller than a day
# America - GPE - Countries, cities, states
# 221 years - DATE - Absolute or relative dates or periods
# 21 months ago - DATE - Absolute or relative dates or periods
# winter - DATE - Absolute or relative dates or periods
# this autumn night - TIME - Times smaller than a day
# Main Street - FAC - Buildings, airports, highways, bridges, etc.
# one - CARDINAL - Numerals that do not fall under another type
# one - CARDINAL - Numerals that do not fall under another type
# first - ORDINAL - "first", "second", etc.
# the Republican Party - ORG - Companies, agencies, institutions, etc.
# the White House - ORG - Companies, agencies, institutions, etc.
# the Democratic Party - ORG - Companies, agencies, institutions, etc.
# tonight - TIME - Times smaller than a day
# Lincoln - ORG - Companies, agencies, institutions, etc.
# Americans - NORP - Nationalities or religious or political groups
# tonight - TIME - Times smaller than a day
# tonight - TIME - Times smaller than a day
# American - NORP - Nationalities or religious or political groups
# America - GPE - Countries, cities, states
# Tonight - TIME - Times smaller than a day
# America - GPE - Countries, cities, states
# America - GPE - Countries, cities, states
# tomorrow - DATE - Absolute or relative dates or periods
# tonight - TIME - Times smaller than a day
# Atlanta - GPE - Countries, cities, states
# millions - CARDINAL - Numerals that do not fall under another type
# one - CARDINAL - Numerals that do not fall under another type
# Ann Nixon Cooper - PERSON - People, including fictional
# 106 years old - DATE - Absolute or relative dates or periods
# two - CARDINAL - Numerals that do not fall under another type
# tonight - TIME - Times smaller than a day
# America - GPE - Countries, cities, states
# American - NORP - Nationalities or religious or political groups
# Montgomery - ORG - Companies, agencies, institutions, etc.
# Birmingham - GPE - Countries, cities, states
# Selma - GPE - Countries, cities, states
# Atlanta - GPE - Countries, cities, states
# the moon - LOC - Non-GPE locations, mountain ranges, bodies of water
# Berlin - GPE - Countries, cities, states
# this year - DATE - Absolute or relative dates or periods
# 106 years - DATE - Absolute or relative dates or periods
# America - GPE - Countries, cities, states
# hours - TIME - Times smaller than a day
# America - GPE - Countries, cities, states
# America - GPE - Countries, cities, states
# tonight - TIME - Times smaller than a day
# the next century - DATE - Absolute or relative dates or periods
# Ann Nixon Cooper - PERSON - People, including fictional
# American - NORP - Nationalities or religious or political groups
# El total de entidades mostradas en el texto es de: 85

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# El atributo .ents contiene todas las entidades de la oración. Luego, se utiliza un ciclo for para recorrer todas las entidades. El atributo .label_ contiene la etiqueta de cada entidad. La cual puede obtenerse su explicación con la función spacy.explain.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 7.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades soporta Spacy?, ¿Qué significa cada una?</span>
#
# <b>Nota</b>: Debes escribir el código que liste las entidades disponibles y la explicación de las mismas. El listado sin código se considerará respuesta incompleta.

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
total_ner_labels = 0
for label in nlp.pipe_labels["ner"]:
    print(label + ' - ' + spacy.explain(label))
    total_ner_labels += 1
print('Total of ner labels supported by sPaCy: ' + str(total_ner_labels))
# Out:
# CARDINAL - Numerals that do not fall under another type
# DATE - Absolute or relative dates or periods
# EVENT - Named hurricanes, battles, wars, sports events, etc.
# FAC - Buildings, airports, highways, bridges, etc.
# GPE - Countries, cities, states
# LANGUAGE - Any named language
# LAW - Named documents made into laws.
# LOC - Non-GPE locations, mountain ranges, bodies of water
# MONEY - Monetary values, including unit
# NORP - Nationalities or religious or political groups
# ORDINAL - "first", "second", etc.
# ORG - Companies, agencies, institutions, etc.
# PERCENT - Percentage, including "%"
# PERSON - People, including fictional
# PRODUCT - Objects, vehicles, foods, etc. (not services)
# QUANTITY - Measurements, as of weight or distance
# TIME - Times smaller than a day
# WORK_OF_ART - Titles of books, songs, etc.
# Total of ner labels supported by sPaCy: 18

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# Spacy soporta 18 entidades, las cuales pueden verse mediante .label_['ner'] de el objeto nlp.pipe_labels.
# La explicación de cada entidad se puede obtener con la función spacy.explain.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 8.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades diferentes son reconocidas en el texto?, ¿cuántas hay de cada tipo?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
ents = {}
for ent in doc.ents:
    if ent.label_ in ents:
        ents[ent.label_] += 1
    else:
        ents[ent.label_] = 1

for label, count in ents.items():
    print(f'{label}: {count}')
# Out:
# GPE: 24
# TIME: 16
# ORDINAL: 2
# NORP: 12
# MONEY: 1
# CARDINAL: 8
# DATE: 12
# LOC: 2
# FAC: 1
# ORG: 5
# PERSON: 2

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# En el discurso de Barack Obama, se presentan en total 11 entidades, las cuales pueden verse mediante .label_['ner'] de el objeto nlp.pipe_labels.
# La entidad que aparece con más frecuencia es 'GPE' la cual aparece 24 veces, y se aplica a las instituciones paises, ciudades y estados, esto es lógico debido a que al ser un discurso político está cargado de lugares.
# La entidad tiempo TIME aparece 16 veces, ya que el discurso continuamente da referencia a intervalos de tiempo, menores a un día.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 9.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Explica con tus palabras qué es el código IOB para el reconocimiento de entiedades. Pon un ejemplo, sacado del texto, de una etiqueta de un único token y una etiqueta compuesta por varios tokens.</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# Imprime una etiqueta IOB para un único token
token = doc[153:161]  # Obtener una oracion con un unico token que es IOB
iob_tags = [token.ent_iob_ + "-" + token.ent_type_ if token.ent_type_ else "O" for token in token]
print(f"Secuencia de tokens: {[token.text for token in token]}, Etiqueta IOB: {'-'.join(iob_tags)}")

# Imprime una etiqueta IOB compuesta por varios tokens
phrase = doc[182:195]  # Obtén una secuencia de tokens
iob_tags = [token.ent_iob_ + "-" + token.ent_type_ if token.ent_type_ else "O" for token in phrase]
print(f"Secuencia de tokens: {[token.text for token in phrase]}, Etiqueta IOB: {'-'.join(iob_tags)}")
# Out:
# Secuencia de tokens: ['Americans', 'who', 'sent', 'a', 'message', 'to', 'the', 'world'], Etiqueta IOB: B-NORP-O-O-O-O-O-O-O
# Secuencia de tokens: ['We', 'are', ',', 'and', 'always', 'will', 'be', ',', 'the', 'United', 'States', 'of', 'America'], Etiqueta IOB: O-O-O-O-O-O-O-O-B-GPE-I-GPE-I-GPE-I-GPE-I-GPE

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# El código IOB se utiliza para el reconocimiento de entidades dentro de una cadena de texto. Una etiqueta IOB se puede obtener mediante el atributo .ent_iob_, donde "B" significa que el token empieza una entidad, "I" significa que el token esta dentro de una entidad, "O" significa que el token esta fuera de una entidad.
# Observe que en los ejemplos anteriores, la primera oración contiene un token clasificado como "B", la cual es la palabra "Americans". La segunda oración contiene una entidad compuesta de varios tokens, por lo que el primer token es marcado como B, y todos los demas se marcan como I. Es el caso de "United States of America".

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 10.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Incluye aquí el código generado para poder responder a tu pregunta
# Es la misma respuesta de la pregunta 1
word_count = 0
for token in doc:
    if not token.is_punct and not token.is_space: # si el token no es punto ni espacio, entonces es una palabra
        word_count += 1
print(str(word_count) + ' palabras')
# Out:
# 1686 palabras

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>
# La pregunta fue contestada en 1).
#
# En total hay 1686 palabras no clasificadas ni como signos de puntuación ni como espacios.
